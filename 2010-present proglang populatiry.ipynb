# %% [markdown]
# # Programming languages prediction

# %% [markdown]
# Importing libraries

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
import seaborn as sns
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn import metrics

from sklearn.model_selection import train_test_split
import sklearn.linear_model as lm

# %% [markdown]
# Downloading all the data to Pandas DataFrames

# %%
df_2010=pd.read_excel("2010.xlsx")
df_2011=pd.read_excel("2011.xlsx")
df_2012=pd.read_excel("2012.xlsx")
df_2013=pd.read_excel("2013.xlsx")
df_2014=pd.read_excel("2014.xlsx")
df_2015=pd.read_excel("2015.xlsx")
df_2016=pd.read_excel("2016.xlsx")
df_2017=pd.read_excel("2017.xlsx")
df_2018=pd.read_excel("2018.xlsx")
df_2019=pd.read_excel("2019.xlsx")

# %% [markdown]
# Check DataFrames

# %%
df_2010
# Out:
#    Rank     Language   Share
# 0     1       Python   6.86%
# 1     2         Java  22.33%
# 2     3   Javascript    1.9%
# 3     4           C#  22.77%
# 4     5          PHP  16.31%
# 5     6        C/C++  14.99%
# 6     7  Objective-C  2.87 %
# 7     8         Ruby   3.71%

# %%
df_2011
# Out:
#    Rank     Language   Share
# 0     1       Python   6.29%
# 1     2         Java  20.38%
# 2     3   Javascript   2.6 %
# 3     4           C#  22.33%
# 4     5          PHP  17.35%
# 5     6        C/C++  13.86%
# 6     7  Objective-C  3.06 %
# 7     8         Ruby   4.05%

# %%
df_2012
# Out:
#    Rank     Language   Share
# 0     1       Python   6.33%
# 1     2         Java  26.19%
# 2     3   Javascript  3.71 %
# 3     4           C#  21.26%
# 4     5          PHP  14.5 %
# 5     6        C/C++  12.48%
# 6     7  Objective-C  3.71 %
# 7     8         Ruby    3.8%

# %%
df_2013
# Out:
#    Rank     Language    Share
# 0     1       Python    6.65%
# 1     2         Java   24.50%
# 2     3   Javascript   5.45 %
# 3     4           C#   21.34%
# 4     5          PHP  15.23 %
# 5     6        C/C++   10.49%
# 6     7  Objective-C   3.92 %
# 7     8         Ruby    3.13%

# %%
df_2014
# Out:
#    Rank     Language    Share
# 0     1       Python    6.26%
# 1     2         Java   25.15%
# 2     3   Javascript   7.56 %
# 3     4           C#   18.83%
# 4     5          PHP  14.35 %
# 5     6        C/C++   10.61%
# 6     7  Objective-C   4.93 %
# 7     8         Ruby    3.78%

# %%
df_2015
# Out:
#    Rank     Language    Share
# 0     1       Python    7.04%
# 1     2         Java   25.01%
# 2     3   Javascript  11.04 %
# 3     4           C#   16.7 %
# 4     5          PHP   14.4 %
# 5     6        C/C++    8.31%
# 6     7  Objective-C   3.85 %
# 7     8         Ruby     4.3%

# %%
df_2016
# Out:
#    Rank     Language   Share
# 0     1       Python  14.69%
# 1     2         Java  22.43%
# 2     3   Javascript  9.86 %
# 3     4           C#  13.01%
# 4     5          PHP  12.8 %
# 5     6        C/C++   7.26%
# 6     7  Objective-C  3.95 %
# 7     8         Ruby    2.7%

# %%
df_2017
# Out:
#    Rank     Language   Share   Trend
# 0     1       Python  18.6 %  +4.7 %
# 1     2         Java  21.4 %  -1.8 %
# 2     3   Javascript   8.0 %  -0.2 %
# 3     4           C#   7.6 %  -0.5 %
# 4     5          PHP   8.2 %  -1.2 %
# 5     6        C/C++   6.3 %  -0.4 %
# 6     7  Objective-C   3.9 %  -0.6 %
# 7     8         Ruby   1.8 %  -0.3 %

# %%
df_2018
# Out:
#    Rank     Language    Share   Trend
# 0     1       Python  24.58 %  +4.7 %
# 1     2         Java  22.14 %  -1.8 %
# 2     3   Javascript   8.41 %  -0.2 %
# 3     4           C#   7.74 %  -0.5 %
# 4     5          PHP   7.77 %  -1.2 %
# 5     6        C/C++   6.22 %  -0.4 %
# 6     7  Objective-C   3.33 %  -0.6 %
# 7     8         Ruby   1.62 %  -0.3 %

# %%
df_2019
# Out:
#    Rank     Language    Share   Trend
# 0     1       Python  28.08 %  +4.7 %
# 1     2         Java  20.51 %  -1.8 %
# 2     3   Javascript   8.29 %  -0.2 %
# 3     4           C#   7.41 %  -0.5 %
# 4     5          PHP   6.96 %  -1.2 %
# 5     6        C/C++   5.76 %  -0.4 %
# 6     7  Objective-C   2.82 %  -0.6 %
# 7     8         Ruby   1.42 %  -0.3 %

# %% [markdown]
# Editing DataFrames. Deleting unnecessary columns, renaming columns

# %%
df_2010.drop(['Rank'], inplace=True, axis=1)
#df_2010.set_index('Language', inplace=True)
df_2010.rename(columns={'Share':'2010'}, inplace=True)
df_2010.head()
# Out:
#      Language    2010
# 0      Python   6.86%
# 1        Java  22.33%
# 2  Javascript    1.9%
# 3          C#  22.77%
# 4         PHP  16.31%

# %%
df_2011.drop(['Rank'], inplace=True, axis=1)
#df_2011.set_index('Language', inplace=True)
df_2011.rename(columns={'Share':'2011'}, inplace=True)
df_2011.head()
# Out:
#      Language    2011
# 0      Python   6.29%
# 1        Java  20.38%
# 2  Javascript   2.6 %
# 3          C#  22.33%
# 4         PHP  17.35%

# %%
df_2012.drop(['Rank'], inplace=True, axis=1)
#df_2012.set_index('Language', inplace=True)
df_2012.rename(columns={'Share':'2012'}, inplace=True)
df_2012.head()
# Out:
#      Language    2012
# 0      Python   6.33%
# 1        Java  26.19%
# 2  Javascript  3.71 %
# 3          C#  21.26%
# 4         PHP  14.5 %

# %%
df_2013.drop(['Rank'], inplace=True, axis=1)
#df_2013.set_index('Language', inplace=True)
df_2013.rename(columns={'Share':'2013'}, inplace=True)
df_2013.head()
# Out:
#      Language     2013
# 0      Python    6.65%
# 1        Java   24.50%
# 2  Javascript   5.45 %
# 3          C#   21.34%
# 4         PHP  15.23 %

# %%
df_2014.drop(['Rank'], inplace=True, axis=1)
#df_2014.set_index('Language', inplace=True)
df_2014.rename(columns={'Share':'2014'}, inplace=True)
df_2014.head()
# Out:
#      Language     2014
# 0      Python    6.26%
# 1        Java   25.15%
# 2  Javascript   7.56 %
# 3          C#   18.83%
# 4         PHP  14.35 %

# %%
df_2015.drop(['Rank'], inplace=True, axis=1)
#df_2015.set_index('Language', inplace=True)
df_2015.rename(columns={'Share':'2015'}, inplace=True)
df_2015.head()
# Out:
#      Language     2015
# 0      Python    7.04%
# 1        Java   25.01%
# 2  Javascript  11.04 %
# 3          C#   16.7 %
# 4         PHP   14.4 %

# %%
df_2016.drop(['Rank'], inplace=True, axis=1)
#df_2016.set_index('Language', inplace=True)
df_2016.rename(columns={'Share':'2016'}, inplace=True)
df_2016.head()
# Out:
#      Language    2016
# 0      Python  14.69%
# 1        Java  22.43%
# 2  Javascript  9.86 %
# 3          C#  13.01%
# 4         PHP  12.8 %

# %%
df_2017.drop(['Rank', 'Trend'], inplace=True, axis=1)
#df_2017.set_index('Language', inplace=True)
df_2017.rename(columns={'Share':'2017'}, inplace=True)
df_2017.head()
# Out:
#      Language    2017
# 0      Python  18.6 %
# 1        Java  21.4 %
# 2  Javascript   8.0 %
# 3          C#   7.6 %
# 4         PHP   8.2 %

# %%
df_2018.drop(['Rank', 'Trend'], inplace=True, axis=1)
#df_2018.set_index('Language', inplace=True)
df_2018.rename(columns={'Share':'2018'}, inplace=True)
df_2018.head()
# Out:
#      Language     2018
# 0      Python  24.58 %
# 1        Java  22.14 %
# 2  Javascript   8.41 %
# 3          C#   7.74 %
# 4         PHP   7.77 %

# %%
df_2019.drop(['Rank', 'Trend'], inplace=True, axis=1)
#df_2019.set_index('Language', inplace=True)
df_2019.rename(columns={'Share':'2019'}, inplace=True)
df_2019.head()
# Out:
#      Language     2019
# 0      Python  28.08 %
# 1        Java  20.51 %
# 2  Javascript   8.29 %
# 3          C#   7.41 %
# 4         PHP   6.96 %

# %% [markdown]
# Replace "%" symbol and convert columns to float datatype

# %%
df_2010['2010']=df_2010['2010'].replace('\%','',regex=True).astype(float)
df_2011['2011']=df_2011['2011'].replace('\%','',regex=True).astype(float)
df_2012['2012']=df_2012['2012'].replace('\%','',regex=True).astype(float)
df_2013['2013']=df_2013['2013'].replace('\%','',regex=True).astype(float)
df_2014['2014']=df_2014['2014'].replace('\%','',regex=True).astype(float)
df_2015['2015']=df_2015['2015'].replace('\%','',regex=True).astype(float)
df_2016['2016']=df_2016['2016'].replace('\%','',regex=True).astype(float)
df_2017['2017']=df_2017['2017'].replace('\%','',regex=True).astype(float)
df_2018['2018']=df_2018['2018'].replace('\%','',regex=True).astype(float)
df_2019['2019']=df_2019['2019'].replace('\%','',regex=True).astype(float)

# %% [markdown]
# Counting sum and give percent value out of all variables to 'year' columns

# %%
df_2010['2010']=df_2010['2010']*100/df_2010['2010'].sum()
df_2011['2011']=df_2011['2011']*100/df_2011['2011'].sum()
df_2012['2012']=df_2012['2012']*100/df_2012['2012'].sum()
df_2013['2013']=df_2013['2013']*100/df_2013['2013'].sum()
df_2014['2014']=df_2014['2014']*100/df_2014['2014'].sum()
df_2015['2015']=df_2015['2015']*100/df_2015['2015'].sum()
df_2016['2016']=df_2016['2016']*100/df_2016['2016'].sum()
df_2017['2017']=df_2017['2017']*100/df_2017['2017'].sum()
df_2018['2018']=df_2018['2018']*100/df_2018['2018'].sum()
df_2019['2019']=df_2019['2019']*100/df_2019['2019'].sum()

# %% [markdown]
# Merge all DataFrames into one

# %%
df=pd.merge(df_2010, df_2011, on='Language', how='outer')
df=pd.merge(df, df_2012, on='Language', how='outer')
df=pd.merge(df, df_2013, on='Language', how='outer')
df=pd.merge(df, df_2014, on='Language', how='outer')
df=pd.merge(df, df_2015, on='Language', how='outer')
df=pd.merge(df, df_2016, on='Language', how='outer')
df=pd.merge(df, df_2017, on='Language', how='outer')
df=pd.merge(df, df_2018, on='Language', how='outer')
df=pd.merge(df, df_2019, on='Language', how='outer')
df
# Out:
#       Language       2010       2011       2012       2013       2014  \
# 0       Python   7.477654   6.995107   6.881931   7.331055   6.843774
# 1         Java  24.340528  22.664591  28.473581  27.009150  27.495354
# 2   Javascript   2.071070   2.891459   4.033486   6.008158   8.265005
# 3           C#  24.820144  24.833185  23.113720  23.525521  20.585984
# 4          PHP  17.778504  19.294929  15.764297  16.789770  15.688204
# 5        C/C++  16.339656  15.413701  13.568167  11.564326  11.599432
# 6  Objective-C   3.128406   3.403025   4.033486   4.321464   5.389745
# 7         Ruby   4.044037   4.504004   4.131333   3.450557   4.132502
#
#         2015       2016       2017       2018       2019
# 0   7.766133  16.943483  24.538259  30.045227  34.560000
# 1  27.589630  25.870819  28.232190  27.062706  25.243077
# 2  12.178709  11.372549  10.554090  10.279917  10.203077
# 3  18.422504  15.005767  10.026385   9.460946   9.120000
# ...

# %% [markdown]
# Using LinearRegression ML algorithm. Splitting all the data to train and test. Getting 'intercept' and 'coef' values

# %%
X = df[['2010','2011','2012','2013','2014','2015','2015','2016','2017','2018']].values
y = df['2019'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
regressor = lm.LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
#To retrieve the intercept:
print(regressor.intercept_)
#For retrieving the slope:
print(regressor.coef_)
# Out:
# 1.4906190645450987
# [ 0.25996052 -0.39082039 -0.44909238  0.7348444   0.04897748 -0.24843867
#  -0.24843867  0.18966636 -0.33137154  1.33146112]

# %% [markdown]
# Test forecasting

# %%
y_pred = regressor.predict(X_test)
df_1 = pd.DataFrame({'Actual': y_test.flatten(), 'Forecasted': y_pred.flatten()})
df_1
# Out:
#      Actual  Forecasted
# 0  3.470769    5.070543

# %% [markdown]
# Visualizing accuracy of forecasted and actual values

# %%
df1 = df_1.head()
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# Setting 'Language' column as index of DataFrame

# %%
df.set_index('Language', inplace=True)

# %% [markdown]
# Using LinearRegression formula for making forecasting to the next year

# %% [markdown]
# [Linear Regression Formula](https://github.com/togzhanbl/ProgLangForecasting/blob/master/Аннотация%202019-06-15%20203806.jpg)

# %%
# x - таблица с исходными данными факторов (x1, x2, x3)
x = df.iloc[:,:]
# y - таблица с исходными данными зависимой переменной
x
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# Language
# Python        7.477654   6.995107   6.881931   7.331055   6.843774   7.766133
# Java         24.340528  22.664591  28.473581  27.009150  27.495354  27.589630
# Javascript    2.071070   2.891459   4.033486   6.008158   8.265005  12.178709
# C#           24.820144  24.833185  23.113720  23.525521  20.585984  18.422504
# PHP          17.778504  19.294929  15.764297  16.789770  15.688204  15.885273
# C/C++        16.339656  15.413701  13.568167  11.564326  11.599432   9.167126
# Objective-C   3.128406   3.403025   4.033486   4.321464   5.389745   4.247104
# Ruby          4.044037   4.504004   4.131333   3.450557   4.132502   4.743519
#
#                   2016       2017       2018       2019
# Language
# Python       16.943483  24.538259  30.045227  34.560000
# Java         25.870819  28.232190  27.062706  25.243077
# Javascript   11.372549  10.554090  10.279917  10.203077
# ...

# %%
y_pred = regressor.intercept_ + np.sum(regressor.coef_ * x, axis=1)
y_pred
# Out:
# Language
# Python         37.906857
# Java           24.082737
# Javascript     10.236668
# C#              8.757842
# PHP             7.293795
# C/C++           6.825212
# Objective-C     4.663298
# Ruby            1.833365
# dtype: float64

# %% [markdown]
# Setting forecasted values to the next year

# %%
df['2020']=y_pred
df
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# Language
# Python        7.477654   6.995107   6.881931   7.331055   6.843774   7.766133
# Java         24.340528  22.664591  28.473581  27.009150  27.495354  27.589630
# Javascript    2.071070   2.891459   4.033486   6.008158   8.265005  12.178709
# C#           24.820144  24.833185  23.113720  23.525521  20.585984  18.422504
# PHP          17.778504  19.294929  15.764297  16.789770  15.688204  15.885273
# C/C++        16.339656  15.413701  13.568167  11.564326  11.599432   9.167126
# Objective-C   3.128406   3.403025   4.033486   4.321464   5.389745   4.247104
# Ruby          4.044037   4.504004   4.131333   3.450557   4.132502   4.743519
#
#                   2016       2017       2018       2019       2020
# Language
# Python       16.943483  24.538259  30.045227  34.560000  37.906857
# Java         25.870819  28.232190  27.062706  25.243077  24.082737
# ...

# %% [markdown]
# Repeat the steps in order to find the values of the next years

# %%
# x - таблица с исходными данными факторов (x1, x2, x3)
x = df[['2010','2011','2012','2013','2014','2015','2015','2016','2017','2018','2019']].values
# y - таблица с исходными данными зависимой переменной
y = df['2020'].values
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=0)
regressor.fit(X_train, y_train) #training the algorithm
y_pred = regressor.predict(X_test)
print(regressor.intercept_)
#For retrieving the slope:
print(regressor.coef_)
df_1 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df_1
# Out:
# 1.0083967015821482
# [ 0.20929521 -0.29861713 -0.23704521  0.3170735   0.15465927 -0.08195092
#  -0.08195092 -0.09255642 -0.40983017  0.33088417  1.11767404]
#      Actual  Predicted
# 0  4.663298    3.89424

# %%
x=df.iloc[:,:]
x
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# Language
# Python        7.477654   6.995107   6.881931   7.331055   6.843774   7.766133
# Java         24.340528  22.664591  28.473581  27.009150  27.495354  27.589630
# Javascript    2.071070   2.891459   4.033486   6.008158   8.265005  12.178709
# C#           24.820144  24.833185  23.113720  23.525521  20.585984  18.422504
# PHP          17.778504  19.294929  15.764297  16.789770  15.688204  15.885273
# C/C++        16.339656  15.413701  13.568167  11.564326  11.599432   9.167126
# Objective-C   3.128406   3.403025   4.033486   4.321464   5.389745   4.247104
# Ruby          4.044037   4.504004   4.131333   3.450557   4.132502   4.743519
#
#                   2016       2017       2018       2019       2020
# Language
# Python       16.943483  24.538259  30.045227  34.560000  37.906857
# Java         25.870819  28.232190  27.062706  25.243077  24.082737
# ...

# %%
y_pred = regressor.intercept_ + np.sum(regressor.coef_ * x, axis=1)
df['2021']=y_pred
df
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# Language
# Python        7.477654   6.995107   6.881931   7.331055   6.843774   7.766133
# Java         24.340528  22.664591  28.473581  27.009150  27.495354  27.589630
# Javascript    2.071070   2.891459   4.033486   6.008158   8.265005  12.178709
# C#           24.820144  24.833185  23.113720  23.525521  20.585984  18.422504
# PHP          17.778504  19.294929  15.764297  16.789770  15.688204  15.885273
# C/C++        16.339656  15.413701  13.568167  11.564326  11.599432   9.167126
# Objective-C   3.128406   3.403025   4.033486   4.321464   5.389745   4.247104
# Ruby          4.044037   4.504004   4.131333   3.450557   4.132502   4.743519
#
#                   2016       2017       2018       2019       2020       2021
# Language
# Python       16.943483  24.538259  30.045227  34.560000  37.906857  39.429461
# Java         25.870819  28.232190  27.062706  25.243077  24.082737  22.585356
# ...

# %%
x = df[['2010','2011','2012','2013','2014','2015','2015','2016','2017','2018','2019', '2020']].values
# y - таблица с исходными данными зависимой переменной
y = df['2021'].values
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=0)
regressor.fit(X_train, y_train) #training the algorithm
y_pred = regressor.predict(X_test)
print(regressor.intercept_)
#For retrieving the slope:
print(regressor.coef_)
# Out:
# 0.8185044628459952
# [ 0.20685709 -0.24616093 -0.21375109  0.16310433  0.21147515  0.01255045
#   0.01255045 -0.14008375 -0.4314998  -0.02551302  0.45239915  0.93683658]

# %%
x=df.iloc[:,:]
x
y_pred = regressor.intercept_ + np.sum(regressor.coef_ * x, axis=1)
df['2022']=y_pred
df
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# Language
# Python        7.477654   6.995107   6.881931   7.331055   6.843774   7.766133
# Java         24.340528  22.664591  28.473581  27.009150  27.495354  27.589630
# Javascript    2.071070   2.891459   4.033486   6.008158   8.265005  12.178709
# C#           24.820144  24.833185  23.113720  23.525521  20.585984  18.422504
# PHP          17.778504  19.294929  15.764297  16.789770  15.688204  15.885273
# C/C++        16.339656  15.413701  13.568167  11.564326  11.599432   9.167126
# Objective-C   3.128406   3.403025   4.033486   4.321464   5.389745   4.247104
# Ruby          4.044037   4.504004   4.131333   3.450557   4.132502   4.743519
#
#                   2016       2017       2018       2019       2020       2021  \
# Language
# Python       16.943483  24.538259  30.045227  34.560000  37.906857  39.429461
# Java         25.870819  28.232190  27.062706  25.243077  24.082737  22.585356
# ...

# %%
x = df[['2010','2011','2012','2013','2014','2015','2015','2016','2017','2018','2019', '2020', '2021']].values
# y - таблица с исходными данными зависимой переменной
y = df['2022'].values
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=0)
regressor.fit(X_train, y_train) #training the algorithm
y_pred = regressor.predict(X_test)
print(regressor.intercept_)
#For retrieving the slope:
print(regressor.coef_)
# Out:
# 0.6500269757468029
# [ 0.21570356 -0.19155404 -0.23178702  0.05654197  0.24447246  0.08002536
#   0.08002536 -0.11270965 -0.38797169 -0.18578677  0.10860952  0.42926329
#   0.84347135]

# %%
x=df.iloc[:,:]
y_pred = regressor.intercept_ + np.sum(regressor.coef_ * x, axis=1)
df['2023']=y_pred
df
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# Language
# Python        7.477654   6.995107   6.881931   7.331055   6.843774   7.766133
# Java         24.340528  22.664591  28.473581  27.009150  27.495354  27.589630
# Javascript    2.071070   2.891459   4.033486   6.008158   8.265005  12.178709
# C#           24.820144  24.833185  23.113720  23.525521  20.585984  18.422504
# PHP          17.778504  19.294929  15.764297  16.789770  15.688204  15.885273
# C/C++        16.339656  15.413701  13.568167  11.564326  11.599432   9.167126
# Objective-C   3.128406   3.403025   4.033486   4.321464   5.389745   4.247104
# Ruby          4.044037   4.504004   4.131333   3.450557   4.132502   4.743519
#
#                   2016       2017       2018       2019       2020       2021  \
# Language
# Python       16.943483  24.538259  30.045227  34.560000  37.906857  39.429461
# Java         25.870819  28.232190  27.062706  25.243077  24.082737  22.585356
# ...

# %%
x = df[['2010','2011','2012','2013','2014','2015','2015','2016','2017','2018','2019', '2020', '2021','2022']].values
# y - таблица с исходными данными зависимой переменной
y = df['2023'].values
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=0)
regressor.fit(X_train, y_train) #training the algorithm
y_pred = regressor.predict(X_test)
x=df.iloc[:,:]
y_pred = regressor.intercept_ + np.sum(regressor.coef_ * x, axis=1)
df['2024']=y_pred
df
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# Language
# Python        7.477654   6.995107   6.881931   7.331055   6.843774   7.766133
# Java         24.340528  22.664591  28.473581  27.009150  27.495354  27.589630
# Javascript    2.071070   2.891459   4.033486   6.008158   8.265005  12.178709
# C#           24.820144  24.833185  23.113720  23.525521  20.585984  18.422504
# PHP          17.778504  19.294929  15.764297  16.789770  15.688204  15.885273
# C/C++        16.339656  15.413701  13.568167  11.564326  11.599432   9.167126
# Objective-C   3.128406   3.403025   4.033486   4.321464   5.389745   4.247104
# Ruby          4.044037   4.504004   4.131333   3.450557   4.132502   4.743519
#
#                   2016       2017       2018       2019       2020       2021  \
# Language
# Python       16.943483  24.538259  30.045227  34.560000  37.906857  39.429461
# Java         25.870819  28.232190  27.062706  25.243077  24.082737  22.585356
# ...

# %% [markdown]
# Sava DataFrame into .csv file

# %%
df.to_csv('proglang2010_2019.csv')

# %% [markdown]
# Transpose the DataFrame and save it into .csv file

# %%
df_T=df.T
df_T
# Out:
# Language     Python       Java  Javascript         C#        PHP      C/C++  \
# 2010       7.477654  24.340528    2.071070  24.820144  17.778504  16.339656
# 2011       6.995107  22.664591    2.891459  24.833185  19.294929  15.413701
# 2012       6.881931  28.473581    4.033486  23.113720  15.764297  13.568167
# 2013       7.331055  27.009150    6.008158  23.525521  16.789770  11.564326
# 2014       6.843774  27.495354    8.265005  20.585984  15.688204  11.599432
# 2015       7.766133  27.589630   12.178709  18.422504  15.885273   9.167126
# 2016      16.943483  25.870819   11.372549  15.005767  14.763552   8.373702
# 2017      24.538259  28.232190   10.554090  10.026385  10.817942   8.311346
# 2018      30.045227  27.062706   10.279917   9.460946   9.497616   7.602983
# 2019      34.560000  25.243077   10.203077   9.120000   8.566154   7.089231
# 2020      37.906857  24.082737   10.236668   8.757842   7.293795   6.825212
# ...

# %%
df_T.to_csv('proglangT.csv')

# %% [markdown]
# Trimming the tables to get the top languages in one year and language information for all years

# %%
df_Python=pd.DataFrame(df_T)
df_Python.drop(['Java','Javascript','C#','PHP','C/C++','Objective-C','Ruby'], inplace=True, axis=1)
df_Python
# Out:
# Language     Python
# 2010       7.477654
# 2011       6.995107
# 2012       6.881931
# 2013       7.331055
# 2014       6.843774
# 2015       7.766133
# 2016      16.943483
# 2017      24.538259
# 2018      30.045227
# 2019      34.560000
# 2020      37.906857
# 2021      39.429461
# 2022      38.929841
# 2023      36.428607
# 2024      32.165905

# %%
df_J=pd.DataFrame(df_T)
df_J.drop(['Python','Javascript','C#','PHP','C/C++','Objective-C','Ruby'], inplace=True, axis=1)
df_Js=pd.DataFrame(df_T)
df_Js.drop(['Java','Python','C#','PHP','C/C++','Objective-C','Ruby'], inplace=True, axis=1)
df_Cs=pd.DataFrame(df_T)
df_Cs.drop(['Java','Javascript','Python','PHP','C/C++','Objective-C','Ruby'], inplace=True, axis=1)
df_P=pd.DataFrame(df_T)
df_P.drop(['Java','Javascript','C#','Python','C/C++','Objective-C','Ruby'], inplace=True, axis=1)
df_C=pd.DataFrame(df_T)
df_C.drop(['Java','Javascript','C#','PHP','Python','Objective-C','Ruby'], inplace=True, axis=1)
df_O=pd.DataFrame(df_T)
df_O.drop(['Java','Javascript','C#','PHP','C/C++','Python','Ruby'], inplace=True, axis=1)
df_R=pd.DataFrame(df_T)
df_R.drop(['Java','Javascript','C#','PHP','C/C++','Objective-C','Python'], inplace=True, axis=1)

# %% [markdown]
# Saving into .csv files

# %%
df_Python.to_csv('python.csv')
df_J.to_csv('java.csv')
df_Js.to_csv('javascript.csv')
df_Cs.to_csv('cs.csv')
df_P.to_csv('php.csv')
df_C.to_csv('c.csv')
df_O.to_csv('objC.csv')
df_R.to_csv('ruby.csv')

# %%
df2010=pd.DataFrame(df)
df2010.drop(['2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2010
# Out:
#                   2010
# Language
# Python        7.477654
# Java         24.340528
# Javascript    2.071070
# C#           24.820144
# PHP          17.778504
# C/C++        16.339656
# Objective-C   3.128406
# Ruby          4.044037

# %%
df2011=pd.DataFrame(df)
df2011.drop(['2010','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2012=pd.DataFrame(df)
df2012.drop(['2011','2010','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2013=pd.DataFrame(df)
df2013.drop(['2011','2012','2010','2014','2015','2016','2017','2018','2019','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2014=pd.DataFrame(df)
df2014.drop(['2011','2012','2013','2010','2015','2016','2017','2018','2019','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2015=pd.DataFrame(df)
df2015.drop(['2011','2012','2013','2014','2010','2016','2017','2018','2019','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2016=pd.DataFrame(df)
df2016.drop(['2011','2012','2013','2014','2015','2010','2017','2018','2019','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2017=pd.DataFrame(df)
df2017.drop(['2011','2012','2013','2014','2015','2016','2010','2018','2019','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2018=pd.DataFrame(df)
df2018.drop(['2011','2012','2013','2014','2015','2016','2017','2010','2019','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2019=pd.DataFrame(df)
df2019.drop(['2011','2012','2013','2014','2015','2016','2017','2018','2010','2020','2021','2022','2023','2024'],inplace=True, axis=1)
df2020=pd.DataFrame(df)
df2020.drop(['2011','2012','2013','2014','2015','2016','2017','2018','2019','2010','2021','2022','2023','2024'],inplace=True, axis=1)
df2021=pd.DataFrame(df)
df2021.drop(['2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2010','2022','2023','2024'],inplace=True, axis=1)
df2022=pd.DataFrame(df)
df2022.drop(['2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2010','2023','2024'],inplace=True, axis=1)
df2023=pd.DataFrame(df)
df2023.drop(['2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022','2010','2024'],inplace=True, axis=1)
df2024=pd.DataFrame(df)
df2024.drop(['2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022','2023','2010'],inplace=True, axis=1)

# %%
df2010.to_csv('top2010.csv')
df2011.to_csv('top2011.csv')
df2012.to_csv('top2012.csv')
df2013.to_csv('top2013.csv')
df2014.to_csv('top2014.csv')
df2015.to_csv('top2015.csv')
df2016.to_csv('top2016.csv')
df2017.to_csv('top2017.csv')
df2018.to_csv('top2018.csv')
df2019.to_csv('top2019.csv')
df2020.to_csv('top2020.csv')
df2021.to_csv('top2021.csv')
df2022.to_csv('top2022.csv')
df2023.to_csv('top2023.csv')
df2024.to_csv('top2024.csv')
